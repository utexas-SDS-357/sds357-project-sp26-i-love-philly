# %% [markdown]
# # Phillies Data Wrangling

# %%
import pandas as pd
import numpy as np
import folium

# %% [markdown]
# ## Import Data Sets

# %%
philly_stops = pd.read_csv("../data/PHILLY_STOPS_DATA_WITH_GAME_INDICATORS.csv")
# Out:
# /var/folders/k9/6ttfwb0s7ssb63rlmgdbybc80000gn/T/ipykernel_3373/2849353646.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   philly_stops = pd.read_csv("../data/PHILLY_STOPS_DATA_WITH_GAME_INDICATORS.csv")

# %%
philly_stops
# Out:
#         raw_row_number        date      time                location  \
# 0               411981  2014-01-01  01:14:00                     NaN
# 1               407442  2014-01-01  01:57:00                     NaN
# 2               217556  2014-01-01  03:30:00    3400 BLOCK SPRUCE ST
# 3               217557  2014-01-01  03:40:00    3400 BLOCK SPRUCE ST
# 4               230988  2014-01-01  08:30:00  N 56TH ST / UPLAND WAY
# ...                ...         ...       ...                     ...
# 1865091        1791698  2018-04-14  21:36:00  S 59TH ST / ELMWOOD AV
# 1865092        1789312  2018-04-14  22:01:00    2600 BLOCK JUDSON ST
# 1865093        1791237  2018-04-14  22:48:00    500 BLOCK E OLNEY AV
# 1865094        1791243  2018-04-14  22:48:00    500 BLOCK E OLNEY AV
# 1865095        1791232  2018-04-14  23:10:00   200 BLOCK W LEHIGH AV
#
#                lat        lng  district service_area  subject_age  \
# 0              NaN        NaN      19.0          191         31.0
# 1              NaN        NaN      12.0          121         21.0
# 2        39.950424 -75.192680      18.0          183         24.0
# 3        39.950424 -75.192680      18.0          183         20.0
# 4        39.983712 -75.234188      19.0          193         31.0
# ...            ...        ...       ...          ...          ...
# 1865091  39.928084 -75.221956      12.0          123         60.0
# 1865092  39.998242 -75.175190      39.0          393         33.0
# 1865093  40.033812 -75.114429      35.0          352         21.0
# 1865094  40.033812 -75.114429      35.0          352         22.0
# 1865095  39.991461 -75.134880      25.0          253         69.0
#
#                    subject_race  ... raw_individual_contraband  \
# 0                         black  ...                      True
# 1                         black  ...                     False
# 2                         black  ...                     False
# 3                         black  ...                     False
# 4                         black  ...                     False
# ...                         ...  ...                       ...
# 1865091                   black  ...                     False
# 1865092  asian/pacific islander  ...                     False
# 1865093                   black  ...                     False
# 1865094                   black  ...                     False
# 1865095                   black  ...                     False
#
#         raw_vehicle_contraband  eagles_home_game eagles_away_game  \
# 0                        False             False            False
# 1                        False             False            False
# 2                        False             False            False
# 3                        False             False            False
# 4                        False             False            False
# ...                        ...               ...              ...
# 1865091                  False             False            False
# 1865092                  False             False            False
# 1865093                  False             False            False
# 1865094                  False             False            False
# 1865095                  False             False            False
#
#         76ers_home_game  76ers_away_game  phillies_home_game  \
# 0                  True            False               False
# 1                  True            False               False
# 2                  True            False               False
# 3                  True            False               False
# 4                  True            False               False
# ...                 ...              ...                 ...
# 1865091           False            False                True
# 1865092           False            False                True
# 1865093           False            False                True
# 1865094           False            False                True
# 1865095           False            False                True
#
#          phillies_away_game  flyers_home_game flyers_away_game
# 0                     False             False            False
# 1                     False             False            False
# 2                     False             False            False
# 3                     False             False            False
# 4                     False             False            False
# ...                     ...               ...              ...
# 1865091               False             False            False
# 1865092               False             False            False
# 1865093               False             False            False
# 1865094               False             False            False
# 1865095               False             False            False
#
# [1865096 rows x 30 columns]

# %%
phillies = pd.read_csv("../data/cleanedPhilliesData.csv")
phillies
# Out:
#      Game        Day        Date StartTime  LOG   EndTime  DayGame  Rank  \
# 0       1     Monday  2014-03-31  14:05:00  216  17:41:00        1     1
# 1       2    Tuesday  2014-04-01  20:05:00  194  23:19:00        0     3
# 2       3  Wednesday  2014-04-02  20:05:00  182  23:07:00        0     4
# 3       4     Friday  2014-04-04  14:20:00  196  17:36:00        1     4
# 4       5   Saturday  2014-04-05  14:20:00  173  17:13:00        1     3
# ..    ...        ...         ...       ...  ...       ...      ...   ...
# 806   158  Wednesday  2018-09-26  20:40:00  171  23:31:00        0     3
# 807   159   Thursday  2018-09-27  15:10:00  186  18:16:00        1     3
# 808   160     Friday  2018-09-28  19:05:00  222  22:47:00        0     3
# 809   161   Saturday  2018-09-29  19:05:00  163  21:48:00        0     3
# 810   162     Sunday  2018-09-30  15:05:00  177  18:02:00        1     3
#
#       CLI  Home  ...  TeamScore OppScore  PointDiff  Win  Walkoff  Season  \
# 0    0.96     1  ...         14       10          4    1        0    2014
# 1    0.98     1  ...          2        3         -1    0        1    2014
# 2    0.88     1  ...          3        4         -1    0        1    2014
# 3    0.88     1  ...          7        2          5    1        0    2014
# 4    0.92     1  ...          2        0          2    1        0    2014
# ..    ...   ...  ...        ...      ...        ...  ...      ...     ...
# 806  0.00     1  ...          0       14        -14    0        0    2018
# 807  0.00     1  ...          3        5         -2    0        0    2018
# 808  0.00     0  ...          2       10         -8    0        0    2018
# 809  0.00     0  ...          3        0          3    1        0    2018
# 810  0.00     0  ...          3        1          2    1        0    2018
#
#      Streak  Rivalry  Mets  Braves
# 0         1        0     0       0
# 1        -1        0     0       0
# 2        -2        0     0       0
# 3         1        0     0       0
# 4         2        0     0       0
# ..      ...      ...   ...     ...
# 806      -7        0     0       0
# 807      -8        0     0       0
# 808      -9        1     0       1
# 809       1        1     0       1
# 810       2        1     0       1
#
# [811 rows x 22 columns]

# %%
phillies.columns
# Out:
# Index(['Game', 'Day', 'Date', 'StartTime', 'LOG', 'EndTime', 'DayGame', 'Rank',
#        'CLI', 'Home', 'Attendance', 'Opp', 'TeamScore', 'OppScore',
#        'PointDiff', 'Win', 'Walkoff', 'Season', 'Streak', 'Rivalry', 'Mets',
#        'Braves'],
#       dtype='object')

# %%
philly_stops.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'location', 'lat', 'lng', 'district',
#        'service_area', 'subject_age', 'subject_race', 'subject_sex', 'type',
#        'arrest_made', 'outcome', 'contraband_found', 'frisk_performed',
#        'search_conducted', 'search_person', 'search_vehicle', 'raw_race',
#        'raw_individual_contraband', 'raw_vehicle_contraband',
#        'eagles_home_game', 'eagles_away_game', '76ers_home_game',
#        '76ers_away_game', 'phillies_home_game', 'phillies_away_game',
#        'flyers_home_game', 'flyers_away_game'],
#       dtype='object')

# %% [markdown]
# ## Parse Date columns

# %%
philly_stops['date'] = pd.to_datetime(philly_stops['date'], format='mixed', errors='coerce').dt.date

# %%
phillies['Date'] = pd.to_datetime(phillies['Date']).dt.date

# Remove dates that occur after the end of the stop data
max_date = philly_stops['date'].max()
phillies = phillies[phillies['Date'] <= max_date]

phillies['Date']
# Out:
# 0      2014-03-31
# 1      2014-04-01
# 2      2014-04-02
# 3      2014-04-04
# 4      2014-04-05
#           ...
# 656    2018-04-09
# 657    2018-04-10
# 658    2018-04-11
# 659    2018-04-13
# 660    2018-04-14
# Name: Date, Length: 661, dtype: object

# %%
philly_stops = philly_stops.dropna(subset=['date'])

# %%
philly_stops['date']
# Out:
# 0          2014-01-01
# 1          2014-01-01
# 2          2014-01-01
# 3          2014-01-01
# 4          2014-01-01
#               ...
# 1865091    2018-04-14
# 1865092    2018-04-14
# 1865093    2018-04-14
# 1865094    2018-04-14
# 1865095    2018-04-14
# Name: date, Length: 1865096, dtype: object

# %% [markdown]
# ## Create square regions

# %% [markdown]
# ### Drop unnecessary columns

# %%
philly_stops.drop(columns=['raw_row_number', 'location', 'district',
       'service_area', 'subject_age', 'subject_race', 'subject_sex', 'type',
       'arrest_made', 'outcome', 'contraband_found', 'frisk_performed',
       'search_conducted', 'search_person', 'search_vehicle', 'raw_race',
       'raw_individual_contraband', 'raw_vehicle_contraband'], inplace=True)
philly_stops.columns
# Out:
# Index(['date', 'time', 'lat', 'lng', 'eagles_home_game', 'eagles_away_game',
#        '76ers_home_game', '76ers_away_game', 'phillies_home_game',
#        'phillies_away_game', 'flyers_home_game', 'flyers_away_game'],
#       dtype='object')

# %% [markdown]
# ### Remove NA value rows

# %%
# Check % of na values first
print(philly_stops.isna().mean() * 100)

philly_stops = philly_stops.dropna()
philly_stops
# Out:
# date                  0.000000
# time                  0.000000
# lat                   5.613491
# lng                   5.613491
# eagles_home_game      0.000000
# eagles_away_game      0.000000
# 76ers_home_game       0.000000
# 76ers_away_game       0.000000
# phillies_home_game    0.000000
# phillies_away_game    0.000000
# flyers_home_game      0.000000
# flyers_away_game      0.000000
# dtype: float64
#                date      time        lat        lng  eagles_home_game  \
# 2        2014-01-01  03:30:00  39.950424 -75.192680             False
# 3        2014-01-01  03:40:00  39.950424 -75.192680             False
# 4        2014-01-01  08:30:00  39.983712 -75.234188             False
# 5        2014-01-01  08:53:00  39.953124 -75.181936             False
# 6        2014-01-01  09:00:00  39.989757 -75.229019             False
# ...             ...       ...        ...        ...               ...
# 1865091  2018-04-14  21:36:00  39.928084 -75.221956             False
# 1865092  2018-04-14  22:01:00  39.998242 -75.175190             False
# 1865093  2018-04-14  22:48:00  40.033812 -75.114429             False
# 1865094  2018-04-14  22:48:00  40.033812 -75.114429             False
# 1865095  2018-04-14  23:10:00  39.991461 -75.134880             False
#
#          eagles_away_game  76ers_home_game  76ers_away_game  \
# 2                   False             True            False
# 3                   False             True            False
# 4                   False             True            False
# 5                   False             True            False
# 6                   False             True            False
# ...                   ...              ...              ...
# 1865091             False            False            False
# 1865092             False            False            False
# 1865093             False            False            False
# 1865094             False            False            False
# 1865095             False            False            False
#
#          phillies_home_game  phillies_away_game  flyers_home_game  \
# 2                     False               False             False
# 3                     False               False             False
# 4                     False               False             False
# 5                     False               False             False
# 6                     False               False             False
# ...                     ...                 ...               ...
# 1865091                True               False             False
# 1865092                True               False             False
# 1865093                True               False             False
# 1865094                True               False             False
# 1865095                True               False             False
#
#          flyers_away_game
# 2                   False
# 3                   False
# 4                   False
# 5                   False
# 6                   False
# ...                   ...
# 1865091             False
# 1865092             False
# 1865093             False
# 1865094             False
# 1865095             False
#
# [1760399 rows x 12 columns]

# %% [markdown]
# ### Convert latitude and longitude to Km based coordinates and create 1 km square grid

# %%
km_to_deg_lat = 1 / 111
mean_lat = philly_stops['lat'].mean()

# Longitude conversion depends on latitude
km_to_deg_lng = 1 / (111 * np.cos(np.radians(mean_lat)))

# Bin each point the floor km
philly_stops['lat_bin'] = np.floor(philly_stops['lat'] / km_to_deg_lat)
philly_stops['lng_bin'] = np.floor(philly_stops['lng'] / km_to_deg_lng)

# Create a region ID
philly_stops['region'] = philly_stops['lat_bin'].astype(int).astype(str) + "_" + philly_stops['lng_bin'].astype(int).astype(str)

print(philly_stops[['lat', 'lng', 'region']].head())
# Out:
#          lat        lng      region
# 2  39.950424 -75.192680  4434_-6395
# 3  39.950424 -75.192680  4434_-6395
# 4  39.983712 -75.234188  4438_-6399
# 5  39.953124 -75.181936  4434_-6394
# 6  39.989757 -75.229019  4438_-6398

# %% [markdown]
# ### Plot grid on a map

# %%
# Center map
center_lat = philly_stops['lat'].mean()
center_lng = philly_stops['lng'].mean()

m = folium.Map(location=[center_lat, center_lng], zoom_start=11)

# Get unique grid cells
unique_cells = philly_stops[['lat_bin', 'lng_bin']].drop_duplicates()

for _, row in unique_cells.iterrows():
    lat_bin = row['lat_bin']
    lng_bin = row['lng_bin']

    # Convert back to coordinates (bottom-left corner)
    lat_min = lat_bin * km_to_deg_lat
    lng_min = lng_bin * km_to_deg_lng

    lat_max = lat_min + km_to_deg_lat
    lng_max = lng_min + km_to_deg_lng

    # Draw rectangle
    folium.Rectangle(
        bounds=[[lat_min, lng_min], [lat_max, lng_max]],
        color='blue',
        weight=1,
        fill=False
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84e6a00bc1566572ff09a330ded3a2ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84e6a00bc1566572ff09a330ded3a2ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84e6a00bc1566572ff09a330ded3a2ce = L.map(
#                 &quot;map_84e6a00bc1566572ff09a330ded3a2ce&quot;,
#                 {
#                     center: [39.99081829529602, -75.15990586703145],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a210eac858194a82502959bab5730c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a210eac858194a82502959bab5730c4.addTo(map_84e6a00bc1566572ff09a330ded3a2ce);
#
#
#             var rectangle_e46caa65b722e9019809bfd1fe1a4fc1 = L.rectangle(
#                 [[39.945945945945944, -75.19781383799486], [39.95495495495495, -75.186054992985]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_84e6a00bc1566572ff09a330ded3a2ce);
#
#
#             var rectangle_47133032745d7486519d887ba5a49733 = L.rectangle(
#                 [[39.98198198198198, -75.24484921803426], [39.99099099099099, -75.23309037302441]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_84e6a00bc1566572ff09a330ded3a2ce);
#
#
#             var rectangle_ad968b29c21363ac3cd2ff6a7d4e459f = L.rectangle(
#                 [[39.945945945945944, -75.186054992985], [39.95495495495495, -75.17429614797516]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_84e6a00bc1566572ff09a330ded3a2ce);
#
#
#             var rectangle_16116c22d192ae32661bd9454fef18db = L.rectangle(
#                 [[39.98198198198198, -75.23309037302441], [39.99099099099099, -75.22133152801456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_84e6a00bc1566572ff09a330ded3a2ce);
#
#
#             var rectangle_3d69ebde91ba1d8a22fc7fe765091a75 = L.rectangle(
#                 [[39.95495495495496, -75.23309037302441], [39.96396396396396, -75.22133152801456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_84e6a00bc1566572ff09a330ded3a2ce);
#
#
#             var rectangle_dd261afde05a821295365ec222a546c8 = L.rectangle(
#                 [[39.97297297

# %%
philly_stops
# Out:
#                date      time        lat        lng  eagles_home_game  \
# 2        2014-01-01  03:30:00  39.950424 -75.192680             False
# 3        2014-01-01  03:40:00  39.950424 -75.192680             False
# 4        2014-01-01  08:30:00  39.983712 -75.234188             False
# 5        2014-01-01  08:53:00  39.953124 -75.181936             False
# 6        2014-01-01  09:00:00  39.989757 -75.229019             False
# ...             ...       ...        ...        ...               ...
# 1865091  2018-04-14  21:36:00  39.928084 -75.221956             False
# 1865092  2018-04-14  22:01:00  39.998242 -75.175190             False
# 1865093  2018-04-14  22:48:00  40.033812 -75.114429             False
# 1865094  2018-04-14  22:48:00  40.033812 -75.114429             False
# 1865095  2018-04-14  23:10:00  39.991461 -75.134880             False
#
#          eagles_away_game  76ers_home_game  76ers_away_game  \
# 2                   False             True            False
# 3                   False             True            False
# 4                   False             True            False
# 5                   False             True            False
# 6                   False             True            False
# ...                   ...              ...              ...
# 1865091             False            False            False
# 1865092             False            False            False
# 1865093             False            False            False
# 1865094             False            False            False
# 1865095             False            False            False
#
#          phillies_home_game  phillies_away_game  flyers_home_game  \
# 2                     False               False             False
# 3                     False               False             False
# 4                     False               False             False
# 5                     False               False             False
# 6                     False               False             False
# ...                     ...                 ...               ...
# 1865091                True               False             False
# 1865092                True               False             False
# 1865093                True               False             False
# 1865094                True               False             False
# 1865095                True               False             False
#
#          flyers_away_game  lat_bin  lng_bin      region
# 2                   False   4434.0  -6395.0  4434_-6395
# 3                   False   4434.0  -6395.0  4434_-6395
# 4                   False   4438.0  -6399.0  4438_-6399
# 5                   False   4434.0  -6394.0  4434_-6394
# 6                   False   4438.0  -6398.0  4438_-6398
# ...                   ...      ...      ...         ...
# 1865091             False   4432.0  -6398.0  4432_-6398
# 1865092             False   4439.0  -6394.0  4439_-6394
# 1865093             False   4443.0  -6388.0  4443_-6388
# 1865094             False   4443.0  -6388.0  4443_-6388
# 1865095             False   4439.0  -6390.0  4439_-6390
#
# [1760399 rows x 15 columns]

# %% [markdown]
# ### Drop extra location columns

# %%
philly_stops.drop(columns=['lat', 'lng'], inplace=True)
philly_stops
# Out:
#                date      time  eagles_home_game  eagles_away_game  \
# 2        2014-01-01  03:30:00             False             False
# 3        2014-01-01  03:40:00             False             False
# 4        2014-01-01  08:30:00             False             False
# 5        2014-01-01  08:53:00             False             False
# 6        2014-01-01  09:00:00             False             False
# ...             ...       ...               ...               ...
# 1865091  2018-04-14  21:36:00             False             False
# 1865092  2018-04-14  22:01:00             False             False
# 1865093  2018-04-14  22:48:00             False             False
# 1865094  2018-04-14  22:48:00             False             False
# 1865095  2018-04-14  23:10:00             False             False
#
#          76ers_home_game  76ers_away_game  phillies_home_game  \
# 2                   True            False               False
# 3                   True            False               False
# 4                   True            False               False
# 5                   True            False               False
# 6                   True            False               False
# ...                  ...              ...                 ...
# 1865091            False            False                True
# 1865092            False            False                True
# 1865093            False            False                True
# 1865094            False            False                True
# 1865095            False            False                True
#
#          phillies_away_game  flyers_home_game  flyers_away_game  lat_bin  \
# 2                     False             False             False   4434.0
# 3                     False             False             False   4434.0
# 4                     False             False             False   4438.0
# 5                     False             False             False   4434.0
# 6                     False             False             False   4438.0
# ...                     ...               ...               ...      ...
# 1865091               False             False             False   4432.0
# 1865092               False             False             False   4439.0
# 1865093               False             False             False   4443.0
# 1865094               False             False             False   4443.0
# 1865095               False             False             False   4439.0
#
#          lng_bin      region
# 2        -6395.0  4434_-6395
# 3        -6395.0  4434_-6395
# 4        -6399.0  4438_-6399
# 5        -6394.0  4434_-6394
# 6        -6398.0  4438_-6398
# ...          ...         ...
# 1865091  -6398.0  4432_-6398
# 1865092  -6394.0  4439_-6394
# 1865093  -6388.0  4443_-6388
# 1865094  -6388.0  4443_-6388
# 1865095  -6390.0  4439_-6390
#
# [1760399 rows x 13 columns]

# %% [markdown]
# ## Aggregate stops by date, region, and hour

# %% [markdown]
# ### Convert time to hour block

# %%
philly_stops['hour'] = pd.to_datetime(philly_stops['time'], format='%H:%M:%S').dt.hour
philly_stops.head()
# Out:
#          date      time  eagles_home_game  eagles_away_game  76ers_home_game  \
# 2  2014-01-01  03:30:00             False             False             True
# 3  2014-01-01  03:40:00             False             False             True
# 4  2014-01-01  08:30:00             False             False             True
# 5  2014-01-01  08:53:00             False             False             True
# 6  2014-01-01  09:00:00             False             False             True
#
#    76ers_away_game  phillies_home_game  phillies_away_game  flyers_home_game  \
# 2            False               False               False             False
# 3            False               False               False             False
# 4            False               False               False             False
# 5            False               False               False             False
# 6            False               False               False             False
#
#    flyers_away_game  lat_bin  lng_bin      region  hour
# 2             False   4434.0  -6395.0  4434_-6395     3
# 3             False   4434.0  -6395.0  4434_-6395     3
# 4             False   4438.0  -6399.0  4438_-6399     8
# 5             False   4434.0  -6394.0  4434_-6394     8
# 6             False   4438.0  -6398.0  4438_-6398     9

# %%
# Drop time column
philly_stops.drop(columns=['time'], inplace=True)
philly_stops.head()
# Out:
#          date  eagles_home_game  eagles_away_game  76ers_home_game  \
# 2  2014-01-01             False             False             True
# 3  2014-01-01             False             False             True
# 4  2014-01-01             False             False             True
# 5  2014-01-01             False             False             True
# 6  2014-01-01             False             False             True
#
#    76ers_away_game  phillies_home_game  phillies_away_game  flyers_home_game  \
# 2            False               False               False             False
# 3            False               False               False             False
# 4            False               False               False             False
# 5            False               False               False             False
# 6            False               False               False             False
#
#    flyers_away_game  lat_bin  lng_bin      region  hour
# 2             False   4434.0  -6395.0  4434_-6395     3
# 3             False   4434.0  -6395.0  4434_-6395     3
# 4             False   4438.0  -6399.0  4438_-6399     8
# 5             False   4434.0  -6394.0  4434_-6394     8
# 6             False   4438.0  -6398.0  4438_-6398     9

# %% [markdown]
# ### Aggregate (count) the number of stops for each date, region, hour combination

# %%
aggregate_philly_stops = (
    philly_stops
    .groupby(['date', 'hour', 'region'])
    .size()
    .reset_index(name='stop_count')
)

aggregate_philly_stops
# Out:
#                date  hour      region  stop_count
# 0        2014-01-01     3  4434_-6395           2
# 1        2014-01-01     8  4434_-6394           1
# 2        2014-01-01     8  4438_-6399           1
# 3        2014-01-01     9  4435_-6398           1
# 4        2014-01-01     9  4436_-6399           1
# ...             ...   ...         ...         ...
# 1087112  2018-04-14    21  4446_-6393           1
# 1087113  2018-04-14    21  4446_-6394           1
# 1087114  2018-04-14    22  4439_-6394           1
# 1087115  2018-04-14    22  4443_-6388           2
# 1087116  2018-04-14    23  4439_-6390           1
#
# [1087117 rows x 4 columns]

# %% [markdown]
# ## Fill 0 stops for any missing combinations

# %%
# Create full date range
all_dates = pd.date_range(start=aggregate_philly_stops['date'].min(), end=aggregate_philly_stops['date'].max(), freq='D')

# Define full hour range (0-23)
all_hours = range(0, 24)

# Get all regions
all_regions = aggregate_philly_stops['region'].unique()

# Create full combination grid
full_index = pd.MultiIndex.from_product(
    [all_dates, all_hours, all_regions],
    names=['date', 'hour', 'region']
)

# Reindex
aggregate_philly_stops = (
    aggregate_philly_stops.set_index(['date', 'hour', 'region'])
      .reindex(full_index)
      .reset_index()
)

# Fill missing values with 0 stops
aggregate_philly_stops['stop_count'] = aggregate_philly_stops['stop_count'].fillna(0).astype(int)
aggregate_philly_stops['date'] = pd.to_datetime(aggregate_philly_stops['date']).dt.date
aggregate_philly_stops
# Out:
#                 date  hour      region  stop_count
# 0         2014-01-01     0  4434_-6395           0
# 1         2014-01-01     0  4434_-6394           0
# 2         2014-01-01     0  4438_-6399           0
# 3         2014-01-01     0  4435_-6398           0
# 4         2014-01-01     0  4436_-6399           0
# ...              ...   ...         ...         ...
# 15099115  2018-04-14    23  4427_-6392           0
# 15099116  2018-04-14    23  4450_-6397           0
# 15099117  2018-04-14    23  4449_-6396           0
# 15099118  2018-04-14    23  4446_-6401           0
# 15099119  2018-04-14    23  4445_-6401           0
#
# [15099120 rows x 4 columns]

# %% [markdown]
# ### Rejoin with home/away labels

# %%
# Get the home/away labels for each date
date_level_data = (
    philly_stops
    .drop_duplicates(subset=['date'])
    .drop(['region', 'hour', 'lat_bin', 'lng_bin'], axis=1)
)

# merge home/away info with aggregated data
aggregate_philly_stops = aggregate_philly_stops.merge(
    date_level_data,
    on='date',
    how='left'
)

# Fill NA home/away days with False
game_cols = [
    'eagles_home_game', 'eagles_away_game',
    '76ers_home_game', '76ers_away_game',
    'phillies_home_game', 'phillies_away_game',
    'flyers_home_game', 'flyers_away_game'
]

aggregate_philly_stops[game_cols] = (
    aggregate_philly_stops[game_cols]
    .fillna(False)
)

aggregate_philly_stops
# Out:
# /var/folders/k9/6ttfwb0s7ssb63rlmgdbybc80000gn/T/ipykernel_3373/291257668.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
#                 date  hour      region  stop_count  eagles_home_game  \
# 0         2014-01-01     0  4434_-6395           0             False
# 1         2014-01-01     0  4434_-6394           0             False
# 2         2014-01-01     0  4438_-6399           0             False
# 3         2014-01-01     0  4435_-6398           0             False
# 4         2014-01-01     0  4436_-6399           0             False
# ...              ...   ...         ...         ...               ...
# 15099115  2018-04-14    23  4427_-6392           0             False
# 15099116  2018-04-14    23  4450_-6397           0             False
# 15099117  2018-04-14    23  4449_-6396           0             False
# 15099118  2018-04-14    23  4446_-6401           0             False
# 15099119  2018-04-14    23  4445_-6401           0             False
#
#           eagles_away_game  76ers_home_game  76ers_away_game  \
# 0                    False             True            False
# 1                    False             True            False
# 2                    False             True            False
# 3                    False             True            False
# 4                    False             True            False
# ...                    ...              ...              ...
# 15099115             False            False            False
# 15099116             False            False            False
# 15099117             False            False            False
# 15099118             False            False            False
# 15099119             False            False            False
#
#           phillies_home_game  phillies_away_game  flyers_home_game  \
# 0                      False               False             False
# 1                      False               False             False
# 2                      False               False             False
# 3                      False               False             False
# 4                      False               False             False
# ...                      ...                 ...               ...
# 15099115                True               False             False
# 15099116                True               False             False
# 15099117                True               False             False
# 15099118                True               False             False
# 15099119                True               False             False
#
#           flyers_away_game
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 15099115             False
# 15099116             False
# 15099117             False
# 15099118             False
# 15099119             False
#
# [15099120 rows x 12 columns]

# %% [markdown]
# ### Calculate Expected number of rows for verification

# %%
len(all_dates)*len(all_hours)*len(all_regions)
# Out:
# 15099120

# %% [markdown]
# ## Add game information and home game flag to stop data

# %% [markdown]
# ### First, check that all gamedays are in the stop data

# %%
missing_dates = phillies.loc[~phillies['Date'].isin(aggregate_philly_stops['date']), 'Date']

# Print any dates that are missing from the stop data
missing_dates
# Out:
# Series([], Name: Date, dtype: object)

# %% [markdown]
#  ### Left join philly stops with Phillies data

# %%
aggregate_philly_stops.columns
# Out:
# Index(['date', 'hour', 'region', 'stop_count', 'eagles_home_game',
#        'eagles_away_game', '76ers_home_game', '76ers_away_game',
#        'phillies_home_game', 'phillies_away_game', 'flyers_home_game',
#        'flyers_away_game'],
#       dtype='object')

# %%
phillies.columns
# Out:
# Index(['Game', 'Day', 'Date', 'StartTime', 'LOG', 'EndTime', 'DayGame', 'Rank',
#        'CLI', 'Home', 'Attendance', 'Opp', 'TeamScore', 'OppScore',
#        'PointDiff', 'Win', 'Walkoff', 'Season', 'Streak', 'Rivalry', 'Mets',
#        'Braves'],
#       dtype='object')

# %%
# Merge (left join keeps all philly_stops rows)
# non-gamedays will have NA in all Phillies columns
merged_df = aggregate_philly_stops.merge(
    phillies,
    how='left',
    left_on='date',
    right_on='Date'
)

# %%
# Check that all gamedays are in the final dataset.
print(merged_df['Date'].nunique())

# Drop the Phillies date column
merged_df = merged_df.drop(columns=['Date'])
merged_df
# Out:
# 654
#                 date  hour      region  stop_count  eagles_home_game  \
# 0         2014-01-01     0  4434_-6395           0             False
# 1         2014-01-01     0  4434_-6394           0             False
# 2         2014-01-01     0  4438_-6399           0             False
# 3         2014-01-01     0  4435_-6398           0             False
# 4         2014-01-01     0  4436_-6399           0             False
# ...              ...   ...         ...         ...               ...
# 15166651  2018-04-14    23  4427_-6392           0             False
# 15166652  2018-04-14    23  4450_-6397           0             False
# 15166653  2018-04-14    23  4449_-6396           0             False
# 15166654  2018-04-14    23  4446_-6401           0             False
# 15166655  2018-04-14    23  4445_-6401           0             False
#
#           eagles_away_game  76ers_home_game  76ers_away_game  \
# 0                    False             True            False
# 1                    False             True            False
# 2                    False             True            False
# 3                    False             True            False
# 4                    False             True            False
# ...                    ...              ...              ...
# 15166651             False            False            False
# 15166652             False            False            False
# 15166653             False            False            False
# 15166654             False            False            False
# 15166655             False            False            False
#
#           phillies_home_game  phillies_away_game  ...  TeamScore  OppScore  \
# 0                      False               False  ...        NaN       NaN
# 1                      False               False  ...        NaN       NaN
# 2                      False               False  ...        NaN       NaN
# 3                      False               False  ...        NaN       NaN
# 4                      False               False  ...        NaN       NaN
# ...                      ...                 ...  ...        ...       ...
# 15166651                True               False  ...        9.0       4.0
# 15166652                True               False  ...        9.0       4.0
# 15166653                True               False  ...        9.0       4.0
# 15166654                True               False  ...        9.0       4.0
# 15166655                True               False  ...        9.0       4.0
#
#           PointDiff  Win Walkoff  Season Streak  Rivalry  Mets  Braves
# 0               NaN  NaN     NaN     NaN    NaN      NaN   NaN     NaN
# 1               NaN  NaN     NaN     NaN    NaN      NaN   NaN     NaN
# 2               NaN  NaN     NaN     NaN    NaN      NaN   NaN     NaN
# 3               NaN  NaN     NaN     NaN    NaN      NaN   NaN     NaN
# 4               NaN  NaN     NaN     NaN    NaN      NaN   NaN     NaN
# ...             ...  ...     ...     ...    ...      ...   ...     ...
# 15166651        5.0  1.0     0.0  2018.0    5.0      0.0   0.0     0.0
# 15166652        5.0  1.0     0.0  2018.0    5.0      0.0   0.0     0.0
# 15166653        5.0  1.0     0.0  2018.0    5.0      0.0   0.0     0.0
# 15166654        5.0  1.0     0.0  2018.0    5.0      0.0   0.0     0.0
# 15166655        5.0  1.0     0.0  2018.0    5.0      0.0   0.0     0.0
#
# [15166656 rows x 33 columns]

# %% [markdown]
# ### Export full dataset

# %%
merged_df.to_csv('../data/phillies_all_days_aggregated_stops.csv')

# %% [markdown]
# ## Add before/after column for gamedays

# %% [markdown]
# ### Filter to just gamedays

# %%
gamedays = merged_df[merged_df['phillies_home_game'] == True].copy()

gamedays.drop(columns=game_cols, inplace=True)
gamedays
# Out:
#                 date  hour      region  stop_count  Game       Day StartTime  \
# 858672    2014-03-31     0  4434_-6395           0   1.0    Monday  14:05:00
# 858673    2014-03-31     0  4434_-6394           0   1.0    Monday  14:05:00
# 858674    2014-03-31     0  4438_-6399           0   1.0    Monday  14:05:00
# 858675    2014-03-31     0  4435_-6398           1   1.0    Monday  14:05:00
# 858676    2014-03-31     0  4436_-6399           1   1.0    Monday  14:05:00
# ...              ...   ...         ...         ...   ...       ...       ...
# 15166651  2018-04-14    23  4427_-6392           0  13.0  Saturday  18:10:00
# 15166652  2018-04-14    23  4450_-6397           0  13.0  Saturday  18:10:00
# 15166653  2018-04-14    23  4449_-6396           0  13.0  Saturday  18:10:00
# 15166654  2018-04-14    23  4446_-6401           0  13.0  Saturday  18:10:00
# 15166655  2018-04-14    23  4445_-6401           0  13.0  Saturday  18:10:00
#
#             LOG   EndTime  DayGame  ...  TeamScore  OppScore  PointDiff  Win  \
# 858672    216.0  17:41:00      1.0  ...       14.0      10.0        4.0  1.0
# 858673    216.0  17:41:00      1.0  ...       14.0      10.0        4.0  1.0
# 858674    216.0  17:41:00      1.0  ...       14.0      10.0        4.0  1.0
# 858675    216.0  17:41:00      1.0  ...       14.0      10.0        4.0  1.0
# 858676    216.0  17:41:00      1.0  ...       14.0      10.0        4.0  1.0
# ...         ...       ...      ...  ...        ...       ...        ...  ...
# 15166651  166.0  20:56:00      0.0  ...        9.0       4.0        5.0  1.0
# 15166652  166.0  20:56:00      0.0  ...        9.0       4.0        5.0  1.0
# 15166653  166.0  20:56:00      0.0  ...        9.0       4.0        5.0  1.0
# 15166654  166.0  20:56:00      0.0  ...        9.0       4.0        5.0  1.0
# 15166655  166.0  20:56:00      0.0  ...        9.0       4.0        5.0  1.0
#
#          Walkoff  Season  Streak  Rivalry  Mets  Braves
# 858672       0.0  2014.0     1.0      0.0   0.0     0.0
# 858673       0.0  2014.0     1.0      0.0   0.0     0.0
# 858674       0.0  2014.0     1.0      0.0   0.0     0.0
# 858675       0.0  2014.0     1.0      0.0   0.0     0.0
# 858676       0.0  2014.0     1.0      0.0   0.0     0.0
# ...          ...     ...     ...      ...   ...     ...
# 15166651     0.0  2018.0     5.0      0.0   0.0     0.0
# 15166652     0.0  2018.0     5.0      0.0   0.0     0.0
# 15166653     0.0  2018.0     5.0      0.0   0.0     0.0
# 15166654     0.0  2018.0     5.0      0.0   0.0     0.0
# 15166655     0.0  2018.0     5.0      0.0   0.0     0.0
#
# [3193488 rows x 25 columns]

# %% [markdown]
# ### Create start/end columns that are rounded to the nearest hour

# %%
gamedays['start_hour'] = (pd.to_datetime(gamedays['StartTime'], format='%H:%M:%S')
                          .dt.round('h') # round to the nearest hour
                          .dt.hour
                          )
gamedays['end_hour'] = (pd.to_datetime(gamedays['EndTime'], format='%H:%M:%S')
                        .dt.round('h') # round to the nearest hour
                        .dt.hour
                        )
gamedays
# Out:
#                 date  hour      region  stop_count  Game       Day StartTime  \
# 858672    2014-03-31     0  4434_-6395           0   1.0    Monday  14:05:00
# 858673    2014-03-31     0  4434_-6394           0   1.0    Monday  14:05:00
# 858674    2014-03-31     0  4438_-6399           0   1.0    Monday  14:05:00
# 858675    2014-03-31     0  4435_-6398           1   1.0    Monday  14:05:00
# 858676    2014-03-31     0  4436_-6399           1   1.0    Monday  14:05:00
# ...              ...   ...         ...         ...   ...       ...       ...
# 15166651  2018-04-14    23  4427_-6392           0  13.0  Saturday  18:10:00
# 15166652  2018-04-14    23  4450_-6397           0  13.0  Saturday  18:10:00
# 15166653  2018-04-14    23  4449_-6396           0  13.0  Saturday  18:10:00
# 15166654  2018-04-14    23  4446_-6401           0  13.0  Saturday  18:10:00
# 15166655  2018-04-14    23  4445_-6401           0  13.0  Saturday  18:10:00
#
#             LOG   EndTime  DayGame  ...  PointDiff  Win  Walkoff  Season  \
# 858672    216.0  17:41:00      1.0  ...        4.0  1.0      0.0  2014.0
# 858673    216.0  17:41:00      1.0  ...        4.0  1.0      0.0  2014.0
# 858674    216.0  17:41:00      1.0  ...        4.0  1.0      0.0  2014.0
# 858675    216.0  17:41:00      1.0  ...        4.0  1.0      0.0  2014.0
# 858676    216.0  17:41:00      1.0  ...        4.0  1.0      0.0  2014.0
# ...         ...       ...      ...  ...        ...  ...      ...     ...
# 15166651  166.0  20:56:00      0.0  ...        5.0  1.0      0.0  2018.0
# 15166652  166.0  20:56:00      0.0  ...        5.0  1.0      0.0  2018.0
# 15166653  166.0  20:56:00      0.0  ...        5.0  1.0      0.0  2018.0
# 15166654  166.0  20:56:00      0.0  ...        5.0  1.0      0.0  2018.0
# 15166655  166.0  20:56:00      0.0  ...        5.0  1.0      0.0  2018.0
#
#          Streak  Rivalry  Mets  Braves  start_hour  end_hour
# 858672      1.0      0.0   0.0     0.0          14        18
# 858673      1.0      0.0   0.0     0.0          14        18
# 858674      1.0      0.0   0.0     0.0          14        18
# 858675      1.0      0.0   0.0     0.0          14        18
# 858676      1.0      0.0   0.0     0.0          14        18
# ...         ...      ...   ...     ...         ...       ...
# 15166651    5.0      0.0   0.0     0.0          18        21
# 15166652    5.0      0.0   0.0     0.0          18        21
# 15166653    5.0      0.0   0.0     0.0          18        21
# 15166654    5.0      0.0   0.0     0.0          18        21
# 15166655    5.0      0.0   0.0     0.0          18        21
#
# [3193488 rows x 27 columns]

# %% [markdown]
# ### Classify each row as before/after/during the game

# %%
conditions = [
    gamedays['hour'] < gamedays['start_hour'],
    (gamedays['hour'] >= gamedays['start_hour']) & (gamedays['hour'] <= gamedays['end_hour']),
    gamedays['hour'] > gamedays['end_hour']
]

choices = ['before', 'during', 'after']

gamedays['game_period'] = np.select(conditions, choices, default="unknown")
gamedays
# Out:
#                 date  hour      region  stop_count  Game       Day StartTime  \
# 858672    2014-03-31     0  4434_-6395           0   1.0    Monday  14:05:00
# 858673    2014-03-31     0  4434_-6394           0   1.0    Monday  14:05:00
# 858674    2014-03-31     0  4438_-6399           0   1.0    Monday  14:05:00
# 858675    2014-03-31     0  4435_-6398           1   1.0    Monday  14:05:00
# 858676    2014-03-31     0  4436_-6399           1   1.0    Monday  14:05:00
# ...              ...   ...         ...         ...   ...       ...       ...
# 15166651  2018-04-14    23  4427_-6392           0  13.0  Saturday  18:10:00
# 15166652  2018-04-14    23  4450_-6397           0  13.0  Saturday  18:10:00
# 15166653  2018-04-14    23  4449_-6396           0  13.0  Saturday  18:10:00
# 15166654  2018-04-14    23  4446_-6401           0  13.0  Saturday  18:10:00
# 15166655  2018-04-14    23  4445_-6401           0  13.0  Saturday  18:10:00
#
#             LOG   EndTime  DayGame  ...  Win  Walkoff  Season  Streak Rivalry  \
# 858672    216.0  17:41:00      1.0  ...  1.0      0.0  2014.0     1.0     0.0
# 858673    216.0  17:41:00      1.0  ...  1.0      0.0  2014.0     1.0     0.0
# 858674    216.0  17:41:00      1.0  ...  1.0      0.0  2014.0     1.0     0.0
# 858675    216.0  17:41:00      1.0  ...  1.0      0.0  2014.0     1.0     0.0
# 858676    216.0  17:41:00      1.0  ...  1.0      0.0  2014.0     1.0     0.0
# ...         ...       ...      ...  ...  ...      ...     ...     ...     ...
# 15166651  166.0  20:56:00      0.0  ...  1.0      0.0  2018.0     5.0     0.0
# 15166652  166.0  20:56:00      0.0  ...  1.0      0.0  2018.0     5.0     0.0
# 15166653  166.0  20:56:00      0.0  ...  1.0      0.0  2018.0     5.0     0.0
# 15166654  166.0  20:56:00      0.0  ...  1.0      0.0  2018.0     5.0     0.0
# 15166655  166.0  20:56:00      0.0  ...  1.0      0.0  2018.0     5.0     0.0
#
#           Mets  Braves  start_hour  end_hour  game_period
# 858672     0.0     0.0          14        18       before
# 858673     0.0     0.0          14        18       before
# 858674     0.0     0.0          14        18       before
# 858675     0.0     0.0          14        18       before
# 858676     0.0     0.0          14        18       before
# ...        ...     ...         ...       ...          ...
# 15166651   0.0     0.0          18        21        after
# 15166652   0.0     0.0          18        21        after
# 15166653   0.0     0.0          18        21        after
# 15166654   0.0     0.0          18        21        after
# 15166655   0.0     0.0          18        21        after
#
# [3193488 rows x 28 columns]

# %%
# Check for any errors (missing values)
gamedays['game_period'].value_counts()
# Out:
# game_period
# before    2381046
# during     440592
# after      371850
# Name: count, dtype: int64

# %% [markdown]
# ## Create km-based coordinates using region

# %%
gamedays[['lat', 'lng']] = gamedays['region'].str.split('_', expand=True)
gamedays
# Out:
#                 date  hour      region  stop_count  Game       Day StartTime  \
# 858672    2014-03-31     0  4434_-6395           0   1.0    Monday  14:05:00
# 858673    2014-03-31     0  4434_-6394           0   1.0    Monday  14:05:00
# 858674    2014-03-31     0  4438_-6399           0   1.0    Monday  14:05:00
# 858675    2014-03-31     0  4435_-6398           1   1.0    Monday  14:05:00
# 858676    2014-03-31     0  4436_-6399           1   1.0    Monday  14:05:00
# ...              ...   ...         ...         ...   ...       ...       ...
# 15166651  2018-04-14    23  4427_-6392           0  13.0  Saturday  18:10:00
# 15166652  2018-04-14    23  4450_-6397           0  13.0  Saturday  18:10:00
# 15166653  2018-04-14    23  4449_-6396           0  13.0  Saturday  18:10:00
# 15166654  2018-04-14    23  4446_-6401           0  13.0  Saturday  18:10:00
# 15166655  2018-04-14    23  4445_-6401           0  13.0  Saturday  18:10:00
#
#             LOG   EndTime  DayGame  ...  Season  Streak  Rivalry  Mets Braves  \
# 858672    216.0  17:41:00      1.0  ...  2014.0     1.0      0.0   0.0    0.0
# 858673    216.0  17:41:00      1.0  ...  2014.0     1.0      0.0   0.0    0.0
# 858674    216.0  17:41:00      1.0  ...  2014.0     1.0      0.0   0.0    0.0
# 858675    216.0  17:41:00      1.0  ...  2014.0     1.0      0.0   0.0    0.0
# 858676    216.0  17:41:00      1.0  ...  2014.0     1.0      0.0   0.0    0.0
# ...         ...       ...      ...  ...     ...     ...      ...   ...    ...
# 15166651  166.0  20:56:00      0.0  ...  2018.0     5.0      0.0   0.0    0.0
# 15166652  166.0  20:56:00      0.0  ...  2018.0     5.0      0.0   0.0    0.0
# 15166653  166.0  20:56:00      0.0  ...  2018.0     5.0      0.0   0.0    0.0
# 15166654  166.0  20:56:00      0.0  ...  2018.0     5.0      0.0   0.0    0.0
# 15166655  166.0  20:56:00      0.0  ...  2018.0     5.0      0.0   0.0    0.0
#
#           start_hour  end_hour  game_period   lat    lng
# 858672            14        18       before  4434  -6395
# 858673            14        18       before  4434  -6394
# 858674            14        18       before  4438  -6399
# 858675            14        18       before  4435  -6398
# 858676            14        18       before  4436  -6399
# ...              ...       ...          ...   ...    ...
# 15166651          18        21        after  4427  -6392
# 15166652          18        21        after  4450  -6397
# 15166653          18        21        after  4449  -6396
# 15166654          18        21        after  4446  -6401
# 15166655          18        21        after  4445  -6401
#
# [3193488 rows x 30 columns]

# %% [markdown]
# ## Clean and Export final dataset

# %% [markdown]
# ### Drop unnecessary columns here (Feel free to add more!)

# %%
final_df = gamedays.copy()
final_df.to_csv('../data/phillies_square_modeling_df.csv')
