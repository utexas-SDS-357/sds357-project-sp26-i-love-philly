# %% [markdown]
# # Phillies Modeling

# %% [markdown]
# ## Read in data

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import ParameterGrid

import xgboost as xgb
import lightgbm as lgb

# %%
df = pd.read_csv("../data/phillies_square_modeling_df.csv", index_col=0)
df.drop(columns=['region', # captured by lat and lng
                 'OppScore', # captured by Team Score and Point diff
                 'Home', # all are home games
                 'Mets', # captured by opponent
                 'Braves', # captured by opponent
                 'StartTime', # Captured by start hour
                 "EndTime"] # Captured by end hour
        , inplace=True)

df
# Out:
#                 date  hour  stop_count  Game       Day    LOG  DayGame  Rank  \
# 858672    2014-03-31     0           0   1.0    Monday  216.0      1.0   1.0
# 858673    2014-03-31     0           0   1.0    Monday  216.0      1.0   1.0
# 858674    2014-03-31     0           0   1.0    Monday  216.0      1.0   1.0
# 858675    2014-03-31     0           1   1.0    Monday  216.0      1.0   1.0
# 858676    2014-03-31     0           1   1.0    Monday  216.0      1.0   1.0
# ...              ...   ...         ...   ...       ...    ...      ...   ...
# 15166651  2018-04-14    23           0  13.0  Saturday  166.0      0.0   2.0
# 15166652  2018-04-14    23           0  13.0  Saturday  166.0      0.0   2.0
# 15166653  2018-04-14    23           0  13.0  Saturday  166.0      0.0   2.0
# 15166654  2018-04-14    23           0  13.0  Saturday  166.0      0.0   2.0
# 15166655  2018-04-14    23           0  13.0  Saturday  166.0      0.0   2.0
#
#            CLI  Attendance  ...  Win  Walkoff  Season  Streak  Rivalry  \
# 858672    0.96     49031.0  ...  1.0      0.0  2014.0     1.0      0.0
# 858673    0.96     49031.0  ...  1.0      0.0  2014.0     1.0      0.0
# 858674    0.96     49031.0  ...  1.0      0.0  2014.0     1.0      0.0
# 858675    0.96     49031.0  ...  1.0      0.0  2014.0     1.0      0.0
# 858676    0.96     49031.0  ...  1.0      0.0  2014.0     1.0      0.0
# ...        ...         ...  ...  ...      ...     ...     ...      ...
# 15166651  0.97     20934.0  ...  1.0      0.0  2018.0     5.0      0.0
# 15166652  0.97     20934.0  ...  1.0      0.0  2018.0     5.0      0.0
# 15166653  0.97     20934.0  ...  1.0      0.0  2018.0     5.0      0.0
# 15166654  0.97     20934.0  ...  1.0      0.0  2018.0     5.0      0.0
# 15166655  0.97     20934.0  ...  1.0      0.0  2018.0     5.0      0.0
#
#           start_hour  end_hour  game_period   lat   lng
# 858672            14        18       before  4434 -6395
# 858673            14        18       before  4434 -6394
# 858674            14        18       before  4438 -6399
# 858675            14        18       before  4435 -6398
# 858676            14        18       before  4436 -6399
# ...              ...       ...          ...   ...   ...
# 15166651          18        21        after  4427 -6392
# 15166652          18        21        after  4450 -6397
# 15166653          18        21        after  4449 -6396
# 15166654          18        21        after  4446 -6401
# 15166655          18        21        after  4445 -6401
#
# [3193488 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['date', 'hour', 'stop_count', 'Game', 'Day', 'LOG', 'DayGame', 'Rank',
#        'CLI', 'Attendance', 'Opp', 'TeamScore', 'PointDiff', 'Win', 'Walkoff',
#        'Season', 'Streak', 'Rivalry', 'start_hour', 'end_hour', 'game_period',
#        'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# ## Define features and one-hot encode categorical variables

# %%
features = ['hour',  'Game', 'Day', 'LOG', 'DayGame', 'Rank',
       'CLI', 'Attendance', 'Opp', 'TeamScore', 'PointDiff', 'Win', 'Walkoff',
       'Season', 'Streak', 'Rivalry', 'start_hour', 'end_hour', 'game_period',
       'lat', 'lng']

X = df[features].copy()
y = df['stop_count']

# Convert categorical text/objects into numbers (One-Hot Encoding)
X = pd.get_dummies(X, columns=['Day', 'Opp',  'Season', 'game_period'],
                   drop_first=True,
                   dtype=int)

X
# Out:
#           hour  Game    LOG  DayGame  Rank   CLI  Attendance  TeamScore  \
# 858672       0   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 858673       0   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 858674       0   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 858675       0   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 858676       0   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# ...        ...   ...    ...      ...   ...   ...         ...        ...
# 15166651    23  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15166652    23  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15166653    23  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15166654    23  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15166655    23  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
#
#           PointDiff  Win  ...  Opp_TBR  Opp_TEX  Opp_TOR  Opp_WSN  \
# 858672          4.0  1.0  ...        0        1        0        0
# 858673          4.0  1.0  ...        0        1        0        0
# 858674          4.0  1.0  ...        0        1        0        0
# 858675          4.0  1.0  ...        0        1        0        0
# 858676          4.0  1.0  ...        0        1        0        0
# ...             ...  ...  ...      ...      ...      ...      ...
# 15166651        5.0  1.0  ...        1        0        0        0
# 15166652        5.0  1.0  ...        1        0        0        0
# 15166653        5.0  1.0  ...        1        0        0        0
# 15166654        5.0  1.0  ...        1        0        0        0
# 15166655        5.0  1.0  ...        1        0        0        0
#
#           Season_2015.0  Season_2016.0  Season_2017.0  Season_2018.0  \
# 858672                0              0              0              0
# 858673                0              0              0              0
# 858674                0              0              0              0
# 858675                0              0              0              0
# 858676                0              0              0              0
# ...                 ...            ...            ...            ...
# 15166651              0              0              0              1
# 15166652              0              0              0              1
# 15166653              0              0              0              1
# 15166654              0              0              0              1
# 15166655              0              0              0              1
#
#           game_period_before  game_period_during
# 858672                     1                   0
# 858673                     1                   0
# 858674                     1                   0
# 858675                     1                   0
# 858676                     1                   0
# ...                      ...                 ...
# 15166651                   0                   0
# 15166652                   0                   0
# 15166653                   0                   0
# 15166654                   0                   0
# 15166655                   0                   0
#
# [3193488 rows x 54 columns]

# %% [markdown]
# ## Split data into training, validation, testing (grouped on date, hour)

# %%
from sklearn.model_selection import GroupShuffleSplit

# Create a unique ID for each date + hour
df['group_id'] = df['date'].astype(str) + "_" + df['hour'].astype(str)

# Use GroupShuffleSplit instead of regular train_test_split

#  Split out test set (20%)
gss1 = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_val_idx, test_idx = next(gss1.split(X, y, groups=df['group_id']))

X_train_val = X.iloc[train_val_idx]
y_train_val = y.iloc[train_val_idx]
groups_train_val = df['group_id'].iloc[train_val_idx]

X_test = X.iloc[test_idx]
y_test = y.iloc[test_idx]

# Split train_val into train (70) and validation (10)
gss2 = GroupShuffleSplit(n_splits=1, test_size=0.125, random_state=42)
train_idx, val_idx = next(gss2.split(X_train_val, y_train_val, groups=groups_train_val))

X_train = X_train_val.iloc[train_idx]
y_train = y_train_val.iloc[train_idx]

X_val = X_train_val.iloc[val_idx]
y_val = y_train_val.iloc[val_idx]

# %%
print(len(X_val), len(X_test), len(X_train))
# Out:
# 318786 638376 2236326

# %%
X_val
# Out:
#           hour  Game    LOG  DayGame  Rank   CLI  Attendance  TeamScore  \
# 860280       4   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 860281       4   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 860282       4   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 860283       4   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# 860284       4   1.0  216.0      1.0   1.0  0.96     49031.0       14.0
# ...        ...   ...    ...      ...   ...   ...         ...        ...
# 15165043    19  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15165044    19  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15165045    19  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15165046    19  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
# 15165047    19  13.0  166.0      0.0   2.0  0.97     20934.0        9.0
#
#           PointDiff  Win  ...  Opp_TBR  Opp_TEX  Opp_TOR  Opp_WSN  \
# 860280          4.0  1.0  ...        0        1        0        0
# 860281          4.0  1.0  ...        0        1        0        0
# 860282          4.0  1.0  ...        0        1        0        0
# 860283          4.0  1.0  ...        0        1        0        0
# 860284          4.0  1.0  ...        0        1        0        0
# ...             ...  ...  ...      ...      ...      ...      ...
# 15165043        5.0  1.0  ...        1        0        0        0
# 15165044        5.0  1.0  ...        1        0        0        0
# 15165045        5.0  1.0  ...        1        0        0        0
# 15165046        5.0  1.0  ...        1        0        0        0
# 15165047        5.0  1.0  ...        1        0        0        0
#
#           Season_2015.0  Season_2016.0  Season_2017.0  Season_2018.0  \
# 860280                0              0              0              0
# 860281                0              0              0              0
# 860282                0              0              0              0
# 860283                0              0              0              0
# 860284                0              0              0              0
# ...                 ...            ...            ...            ...
# 15165043              0              0              0              1
# 15165044              0              0              0              1
# 15165045              0              0              0              1
# 15165046              0              0              0              1
# 15165047              0              0              0              1
#
#           game_period_before  game_period_during
# 860280                     1                   0
# 860281                     1                   0
# 860282                     1                   0
# 860283                     1                   0
# 860284                     1                   0
# ...                      ...                 ...
# 15165043                   0                   1
# 15165044                   0                   1
# 15165045                   0                   1
# 15165046                   0                   1
# 15165047                   0                   1
#
# [318786 rows x 54 columns]

# %%
y_val
# Out:
# 860280      0
# 860281      0
# 860282      0
# 860283      0
# 860284      0
#            ..
# 15165043    0
# 15165044    0
# 15165045    0
# 15165046    0
# 15165047    0
# Name: stop_count, Length: 318786, dtype: int64

# %% [markdown]
# ## Fit Different Models on Validation Set

# %% [markdown]
# ### Define Evaluation Function

# %%
def evaluate_model(model, X, y):
    preds = model.predict(X)
    preds_int = np.rint(preds).astype(int)
    mae = mean_absolute_error(y, preds_int)
    rmse = np.sqrt(mean_squared_error(y, preds_int))
    return mae, rmse

# %% [markdown]
# ### Define Feature Sets

# %%
feature_sets = {
    "all_features": X_val.columns.tolist(),
    "top_features": ["lng", "lat", "hour", 'Day_Monday', 'Day_Saturday',
       'Day_Sunday', 'Day_Thursday', 'Day_Tuesday', 'Day_Wednesday']
}

# %% [markdown]
# ### Define Hyperparameter Grids

# %%
xgb_params = {
    "n_estimators": [100, 300],
    "max_depth": [3, 6],
    "learning_rate": [0.05, 0.1],
    "subsample": [0.8, 1.0],
}

rf_params = {
    "n_estimators": [100, 300],
    "max_depth": [None, 10],
    "min_samples_split": [2, 5],
}

lgb_params = {
    "n_estimators": [100, 300],
    "num_leaves": [31, 50],
    "learning_rate": [0.05, 0.1],
}

# %% [markdown]
# ### Try the different models

# %%
results = []

for feature_set_name, features in feature_sets.items():

    X_tr = X_train[features]
    X_v = X_val[features]

    # # -------------------
    # # XGBOOST
    # # -------------------
    # for params in ParameterGrid(xgb_params):
    #     model = xgb.XGBRegressor(
    #         objective='reg:squarederror',
    #         random_state=42,
    #         **params
    #     )
    #
    #     model.fit(X_tr, y_train)
    #     mae, rmse = evaluate_model(model, X_v, y_val)
    #
    #     results.append({
    #         "model": "XGBoost",
    #         "feature_set": feature_set_name,
    #         "params": params,
    #         "val_mae": mae,
    #         "val_rmse": rmse
    #     })
    #
    # print(results)
    #
    # # # -------------------
    # # # RANDOM FOREST
    # # # -------------------
    # for params in ParameterGrid(rf_params):
    #     model = RandomForestRegressor(
    #         random_state=42,
    #         n_jobs=-1,
    #         **params
    #     )
    #
    #     model.fit(X_tr, y_train)
    #     mae, rmse = evaluate_model(model, X_v, y_val)
    #
    #     results.append({
    #         "model": "RandomForest",
    #         "feature_set": feature_set_name,
    #         "params": params,
    #         "val_mae": mae,
    #         "val_rmse": rmse
    #     })
    # print(results)
    # -------------------
    # LIGHTGBM
    # -------------------
    for params in ParameterGrid(lgb_params):
        model = lgb.LGBMRegressor(
            random_state=42,
            **params
        )

        model.fit(X_tr, y_train)
        mae, rmse = evaluate_model(model, X_v, y_val)

        results.append({
            "model": "LightGBM",
            "feature_set": feature_set_name,
            "params": params,
            "val_mae": mae,
            "val_rmse": rmse
        })
    print(results)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.057452 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051872 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.058889 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.047875 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.045318 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044768 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.059304 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.054107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# [{'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 100, 'num_leaves': 31}, 'val_mae': 0.1196884430307479, 'val_rmse': np.float64(0.4931793417390926)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 100, 'num_leaves': 50}, 'val_mae': 0.11912380091973926, 'val_rmse': np.float64(0.48820574121838906)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 300, 'num_leaves': 31}, 'val_mae': 0.11887912267163551, 'val_rmse': np.float64(0.48324586538461245)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 300, 'num_leaves': 50}, 'val_mae': 0.11876619424943378, 'val_rmse': np.float64(0.4791454324477026)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}, 'val_mae': 0.1192837828511917, 'val_rmse': np.float64(0.4865226066032851)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 50}, 'val_mae': 0.11873796214388335, 'val_rmse': np.float64(0.48254104382683954)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 300, 'num_leaves': 31}, 'val_mae': 0.1190265570006211, 'val_rmse': np.float64(0.4790504934947998)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 300, 'num_leaves': 50}, 'val_mae': 0.11826742705137616, 'val_rmse': np.float64(0.47466277492016773)}]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010456 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009981 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009993 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010456 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010035 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009982 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010025 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010012 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 96
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 9
# [LightGBM] [Info] Start training from score 0.117447
# [{'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 100, 'num_leaves': 31}, 'val_mae': 0.1196884430307479, 'val_rmse': np.float64(0.4931793417390926)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 100, 'num_leaves': 50}, 'val_mae': 0.11912380091973926, 'val_rmse': np.float64(0.48820574121838906)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 300, 'num_leaves': 31}, 'val_mae': 0.11887912267163551, 'val_rmse': np.float64(0.48324586538461245)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.05, 'n_estimators': 300, 'num_leaves': 50}, 'val_mae': 0.11876619424943378, 'val_rmse': np.float64(0.4791454324477026)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}, 'val_mae': 0.1192837828511917, 'val_rmse': np.float64(0.4865226066032851)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 50}, 'val_mae': 0.11873796214388335, 'val_rmse': np.float64(0.48254104382683954)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 300, 'num_leaves': 31}, 'val_mae': 0.1190265570006211, 'val_rmse': np.float64(0.4790504934947998)}, {'model': 'LightGBM', 'feature_set': 'all_features', 'params': {'learning_rate': 0.1, 'n_estimators': 300, 'num_leaves': 50}, 'val_mae': 0.11826742705137616, 'val_rmse': np.float64(0.47466277492016773)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.05, 'n_estimators': 100, 'num_leaves': 31}, 'val_mae': 0.12054795379972771, 'val_rmse': np.float64(0.49565375576025056)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.05, 'n_estimators': 100, 'num_leaves': 50}, 'val_mae': 0.12054795379972771, 'val_rmse': np.float64(0.4910694807356079)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.05, 'n_estimators': 300, 'num_leaves': 31}, 'val_mae': 0.12107809000395249, 'val_rmse': np.float64(0.4888703142820769)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.05, 'n_estimators': 300, 'num_leaves': 50}, 'val_mae': 0.12147647638227525, 'val_rmse': np.float64(0.4874276518718975)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}, 'val_mae': 0.12095575087990063, 'val_rmse': np.float64(0.4903407198768308)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 50}, 'val_mae': 0.12143569667425796, 'val_rmse': np.float64(0.48885748085079944)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.1, 'n_estimators': 300, 'num_leaves': 31}, 'val_mae': 0.121721154630379, 'val_rmse': np.float64(0.48750487323118413)}, {'model': 'LightGBM', 'feature_set': 'top_features', 'params': {'learning_rate': 0.1, 'n_estimators': 300, 'num_leaves': 50}, 'val_mae': 0.12222619562967006, 'val_rmse': np.float64(0.4862968884260775)}]

# %% [markdown]
# ### Compare Results

# %%
results_df = pd.DataFrame(results)

# Sort by validation MAE (or RMSE)
results_df = results_df.sort_values(by="val_rmse")

results_df
# Out:
#        model   feature_set                                             params  \
# 7   LightGBM  all_features  {'learning_rate': 0.1, 'n_estimators': 300, 'n...
# 6   LightGBM  all_features  {'learning_rate': 0.1, 'n_estimators': 300, 'n...
# 3   LightGBM  all_features  {'learning_rate': 0.05, 'n_estimators': 300, '...
# 5   LightGBM  all_features  {'learning_rate': 0.1, 'n_estimators': 100, 'n...
# 2   LightGBM  all_features  {'learning_rate': 0.05, 'n_estimators': 300, '...
# 15  LightGBM  top_features  {'learning_rate': 0.1, 'n_estimators': 300, 'n...
# 4   LightGBM  all_features  {'learning_rate': 0.1, 'n_estimators': 100, 'n...
# 11  LightGBM  top_features  {'learning_rate': 0.05, 'n_estimators': 300, '...
# 14  LightGBM  top_features  {'learning_rate': 0.1, 'n_estimators': 300, 'n...
# 1   LightGBM  all_features  {'learning_rate': 0.05, 'n_estimators': 100, '...
# 13  LightGBM  top_features  {'learning_rate': 0.1, 'n_estimators': 100, 'n...
# 10  LightGBM  top_features  {'learning_rate': 0.05, 'n_estimators': 300, '...
# 12  LightGBM  top_features  {'learning_rate': 0.1, 'n_estimators': 100, 'n...
# 9   LightGBM  top_features  {'learning_rate': 0.05, 'n_estimators': 100, '...
# 0   LightGBM  all_features  {'learning_rate': 0.05, 'n_estimators': 100, '...
# 8   LightGBM  top_features  {'learning_rate': 0.05, 'n_estimators': 100, '...
#
#      val_mae  val_rmse
# 7   0.118267  0.474663
# 6   0.119027  0.479050
# 3   0.118766  0.479145
# 5   0.118738  0.482541
# 2   0.118879  0.483246
# 15  0.122226  0.486297
# 4   0.119284  0.486523
# 11  0.121476  0.487428
# 14  0.121721  0.487505
# 1   0.119124  0.488206
# 13  0.121436  0.488857
# 10  0.121078  0.488870
# 12  0.120956  0.490341
# 9   0.120548  0.491069
# 0   0.119688  0.493179
# 8   0.120548  0.495654

# %% [markdown]
# ### Select Best Model

# %%
best_row = results_df.iloc[0]

best_model_name = best_row["model"]
best_params = best_row["params"]
best_features = feature_sets[best_row["feature_set"]]

print(best_row)
# Out:
# model                                                   LightGBM
# feature_set                                         all_features
# params         {'learning_rate': 0.1, 'n_estimators': 300, 'n...
# val_mae                                                 0.118267
# val_rmse                                                0.474663
# Name: 7, dtype: object

# %% [markdown]
# ## SHAP (using validation set to go backwards and influence variable sets)

# %%
import shap

# Ensure sorted (just in case)
results_df = results_df.sort_values(by="val_rmse").reset_index(drop=True)

top_3 = results_df.head(3)
print(top_3)

def build_model(model_name, params):
    if model_name == "XGBoost":
        return xgb.XGBRegressor(
            objective='reg:squarederror',
            random_state=42,
            **params
        )

    elif model_name == "RandomForest":
        return RandomForestRegressor(
            random_state=42,
            n_jobs=-1,
            **params
        )

    elif model_name == "LightGBM":
        return lgb.LGBMRegressor(
            random_state=42,
            **params
        )

shap_results = []

for i, row in top_3.iterrows():

    model_name = row["model"]
    params = row["params"]
    feature_set_name = row["feature_set"]
    features = feature_sets[feature_set_name]

    print(f"\nRunning SHAP for model {i+1}: {model_name} ({feature_set_name})")

    # Prepare data
    X_tr = X_train[features]
    X_v = X_val[features]

    # Build + fit model
    model = build_model(model_name, params)
    model.fit(X_tr, y_train)

    # Sample validation set (for speed)
    X_sample = X_v.sample(n=min(5000, len(X_v)), random_state=42)

    # SHAP
    explainer = shap.Explainer(model, X_sample)
    shap_values = explainer(X_sample)

    # Store results
    shap_results.append({
        "model": model_name,
        "feature_set": feature_set_name,
        "explainer": explainer,
        "shap_values": shap_values,
        "X_sample": X_sample
    })

    # Plot summary
    shap.summary_plot(shap_values, X_sample)

    # Plot bar (clean importance)
    shap.plots.bar(shap_values)
# Out:
#       model   feature_set                                             params  \
# 0  LightGBM  all_features  {'learning_rate': 0.1, 'n_estimators': 300, 'n...
# 1  LightGBM  all_features  {'learning_rate': 0.1, 'n_estimators': 300, 'n...
# 2  LightGBM  all_features  {'learning_rate': 0.05, 'n_estimators': 300, '...
#
#     val_mae  val_rmse
# 0  0.118267  0.474663
# 1  0.119027  0.479050
# 2  0.118766  0.479145
#
# Running SHAP for model 1: LightGBM (all_features)
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044541 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
#  99%|===================| 4928/5000 [00:16<00:00]
# Running SHAP for model 2: LightGBM (all_features)
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044865 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
#  99%|===================| 4952/5000 [00:13<00:00]
# Running SHAP for model 3: LightGBM (all_features)
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.057322 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
#  98%|===================| 4878/5000 [00:20<00:00]

# %% [markdown]
# +## Fit selected model using training data

# %%
X_tr_final = X_train[best_features]
X_test_final = X_test[best_features]

if best_model_name == "XGBoost":
    final_model = xgb.XGBRegressor(
        objective='reg:squarederror',
        random_state=42,
        **best_params
    )

elif best_model_name == "RandomForest":
    final_model = RandomForestRegressor(
        random_state=42,
        n_jobs=-1,
        **best_params
    )

elif best_model_name == "LightGBM":
    final_model = lgb.LGBMRegressor(
        random_state=42,
        **best_params
    )

final_model.fit(X_tr_final, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044992 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 827
# [LightGBM] [Info] Number of data points in the train set: 2236326, number of used features: 54
# [LightGBM] [Info] Start training from score 0.117447
# LGBMRegressor(n_estimators=300, num_leaves=50, random_state=42)

# %% [markdown]
# ## Final Evaluation on Test Data

# %%
test_mae, test_rmse = evaluate_model(final_model, X_test_final, y_test)

print(f"Final Test MAE: {test_mae:.4f}")
print(f"Final Test RMSE: {test_rmse:.4f}")
# Out:
# Final Test MAE: 0.1166
# Final Test RMSE: 0.4692

# %% [markdown]
# ## Create baseline Model for Comparison

# %%
from sklearn.dummy import DummyRegressor

dummy = DummyRegressor(strategy="mean")
dummy.fit(X_train, y_train)
y_pred = dummy.predict(X_test)

# Round predictions to nearest integer
y_pred_int = np.rint(y_pred).astype(int)

# Evaluate
base_rmse = np.sqrt(mean_squared_error(y_test, y_pred_int))
base_mae = mean_absolute_error(y_test, y_pred_int)

print(f"Baseline MAE: {base_mae:.4f}")
print(f"Baseline RMSE: {base_rmse:.4f}")
# Out:
# Baseline MAE: 0.1172
# Baseline RMSE: 0.5471

# %% [markdown]
# ## SHAP on final model

# %%
X_shap = X_test_final.sample(
    n=min(5000, len(X_test_final)),
    random_state=42
)

explainer = shap.Explainer(final_model, X_shap)
shap_values = explainer(X_shap)

shap.summary_plot(shap_values, X_shap)

shap.plots.bar(shap_values)
# Out:
#  94%|=================== | 4708/5000 [00:15<00:00]
